# %% [markdown]
# # Guided Capstone Project Report - Big Mountain Ski Resort
# ## Context and Business Problem
# The Big Mountain ski resort in Montana receives around 350,000 people every year for skiing and snowboarding activities. So far, the company has used a market-oriented pricing strategy, which consists of charging a premium over the market price average. However, our client is considering a different pricing approach and is looking to increase its revenue. Revenue increase might be accomplished in one of two ways: (1) by increasing ticket prices even higher or (2) by cutting operational costs and therefore increasing profit margins. In this report, I focus on strategy (1) given that the data available for this analysis does not include enough information on costs.

# %% [markdown]
# ## Target Feature and Market Size
# To achieve the client’s goal of improving revenue, I focus my analysis on ticket prices and how the resort might be able to charge a higher premium. While the available data contained both weekend and weekday ticket prices, I decided to focus only on weekend prices for three reasons: (1) the available dataset contained more missing values for weekday prices than weekend prices, (2) there is a roughly 1-to-1 correlation between weekend and weekday ticket prices once the value was above \$100 (Fig. 1A), and (3) our resort currently charges the same ticket prices for both weekends and weekdays. Further, Principal Component Analysis (PCA) of this price data, which is able to explain over 77\% of price variability, suggests no obvious pricing pattern across states (Fig. 1B). For this reason, the analysis presented assumes a nation-wide ski resort market.

# %% [markdown]
# Fig. 1: ![Price_and_PCA.png](attachment:Price_and_PCA.png)

# %% [markdown]
# ## Main Features Controlling Market Prices
# Modeling results suggest 8 features as the main drivers of price, namely vertical drop, snow making acreage, total number of chairs, number of fast Quads, number of runs, length of longest run, number of trams, and the size of the skiable terrain. Big Mountain has a solid standing in the market for most of these features, as can be seen in Figure 2. Perhaps one exception to consider is vertical drop -- while the client is doing well for vertical drop, there are still quite a few resorts with a greater drop.

# %% [markdown]
# Fig. 2:![Feature_Distributions_vs_BigMountain.png](attachment:Feature_Distributions_vs_BigMountain.png)

# %% [markdown]
# Big Mountain’s current ticket price is \\$81. Our modeled price, based on the overall market, is \\$95.87 and could be achieved by the client without any further changes to current facilities. This value is slightly above model error (\\$10.39), suggesting there is indeed room for price improvement. One caveat here is that this model assumes that ticket prices in the market are not mispriced, i.e., they are based on what consumers are willing to pay given the facilities offered. If some resorts are over/underpricing, our modeled ticket price could be biased.

# %% [markdown]
# ## Model Scenarios
# While our modeling efforts highlighted 8 features likely controlling ticket prices in the ski resort market, 4 of them appear to carry the most weight: number of fast Quadas, number of runs, snow making acreage and vertical drop. Based on those, 4 modeling scenarios were considered where Big Mountain improves on its facilities to further increase ticket price (above \\$95.87):
# <ol>
# <p>(1) Closing down up to 10 runs: While closing down one run would not affect the modeled ticket price (\\$95.87), further decreases in the number of runs would cause ticket prices to fall by up to \\$1.75 (10 runs down; Figure 3);</p>
# </ol>

# %% [markdown]
# Fig. 3: ![Scenario1_ClosingRuns.png](attachment:Scenario1_ClosingRuns.png)

# %% [markdown]
# <ol>
# <p> 2. Increasing vertical drop (150 ft) by providing one additional run with one new chair to service it: These changes would allow for a further ticket price increase of \$8.61, amounting to an additional revenue of \$15,065,471;</p>
#
# <p> 3. Similar to scenario 2, but with two additional acres of snow coverage: This change would allow for price and revenue increases of \$9.90 and \$17,322,717, respectively;</p>
#
# <p>4. Increase the longest run by 0.2 miles and add 4 acres of snow coverage: These changes would not allow for any further increase over the modeled ticket price of \$95.87.</p>
# </ol>

# %% [markdown]
# ## Recommendation
# Scenarios 2 and 3 are the only ones that would yield further increases in ticket price. However, scenario 3 is likely to result in higher operational costs than scenario 2, given the need for more snow making machines and machine maintenance. The ROI of scenario 3 is not that much bigger than scenario 2, so I would suggest scenario 2 to business leadership. If possible, our client could do both 1 and 2: close one run (with no penalty on price) and open another one that would allow for the increase in vertical drop. Finally, the additional chair will cost the business \\$1,540,000 in operational cost, which would amount to \\$0.88 per ticket going into cost coverage. All else equal, this would result in a net revenue of \\$13,525,471 (for the combined scenarios 1 and 2).

# %% [markdown]
# ## Future Work
# Here are a few points to consider before/while implementing recommendations:
# <ol>
# <p> 1. The solution proposed here for this business problem is based solely on weekend ticket prices and assumes weekday prices will match weekend prices. Further price analysis would be needed if the client would like to price weekday tickets differently.</p>
# <p> 2. Given that this is a revenue problem, a better understanding of costs would be crucial. In addition to chair lift costs, how much would it cost to manage/set up a new run, for example? </p>
# <p> 3. Another important aspect I would like more information on is where the expected 350,000 visitors come from. If they are mostly local, would a much higher ticket price push them into visiting other MT resorts? This would be good to consider, seen as Big Mountain is already one of the most expensive resorts in MT (Figure 4).</p>

# %% [markdown]
# Fig. 4: ![BigMountain_price_relative_to_MT_market.png](attachment:BigMountain_price_relative_to_MT_market.png)
